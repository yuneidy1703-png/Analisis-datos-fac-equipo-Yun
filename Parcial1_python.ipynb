# %% [markdown]
# <a href="https://colab.research.google.com/github/yuneidy1703-png/Analisis-datos-fac-equipo-Yun/blob/main/Parcial1_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PARCIAL 1
#
# Estudiante: Yuneidy Gutierrez

# %%
#Librerias
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind, chi2_contingency
import seaborn as sns

# %%
#Conectar a drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Leer los datos
df = pd.read_excel('/content/drive/MyDrive/Python/Parcial1/Dat_Ri_Fa_123.xlsx')

# %% [markdown]
# ### **1. Caracterización Simple (15 puntos)**
#
# • Carga del archivo Dat_Ri_Fa_123.xlsx
#
# • Exploración básica: número de registros, columnas, tipos de datos
#
# • Estadísticas descriptivas de variables categóricas principales (use .value_counts())
#
# • Identificación de valores faltantes

# %%
# 1. Caracterización Simple
print("=== INFORMACIÓN GENERAL ===")
print(f"Total de registros: {len(df)}")
print(f"Total de columnas: {len(df.columns)}")
# Out:
# === INFORMACIÓN GENERAL ===
# Total de registros: 310743
# Total de columnas: 19

# %%
#Análisis de tipos de datos
print(f"\n=== TIPOS DE DATOS ===")
print(df.dtypes.value_counts())
# Out:
# === TIPOS DE DATOS ===
# object    16
# int64      3
# Name: count, dtype: int64

# %%
#Analisis de datos faltantes
print("=== ANÁLISIS DE DATOS FALTANTES ===")
missing_data = df.isnull().sum()
missing_percent = (missing_data / len(df)) * 100
print("Top 10 columnas con más datos faltantes:")
missing_info = pd.DataFrame({
'Columna': missing_data.index,
'Datos_Faltantes': missing_data.values,
'Porcentaje': missing_percent.values
}).sort_values('Datos_Faltantes', ascending=False)
print(missing_info.head(10))
# Out:
# === ANÁLISIS DE DATOS FALTANTES ===
# Top 10 columnas con más datos faltantes:
#                                               Columna  Datos_Faltantes  \
# 11                                        descripcion            67587
# 1                                 Criterio Geografico                0
# 0                                             estrato                0
# 2                                    Tipo de Vivienda                0
# 3                         Cod Tenencia de la Vivienda                0
# 5                     Ingreso Economico de la Familia                0
# 4                             Tenencia de la Vivienda                0
# 7   ¿Hubo alguna vez en que usted haya dejado de c...                0
# 8                                   Energía Eléctrica                0
# 9                          Gas natural de red pública                0
#
#     Porcentaje
# 11   21.750128
# 1     0.000000
# 0     0.000000
# 2     0.000000
# 3     0.000000
# ...

# %%
# Estadisticas Descriptivas
# variables categoricas
var_categoricas = df.select_dtypes(include=['object', 'category']).columns

# %%
# Usando (.value_counts())
for col in var_categoricas:
    print(f'\*Estadísticas de la variable: {col}')
    print(df[col].value_counts(normalize=True) * 100)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\*'
# <>:3: SyntaxWarning: invalid escape sequence '\*'
# /tmp/ipython-input-942880740.py:3: SyntaxWarning: invalid escape sequence '\*'
#   print(f'\*Estadísticas de la variable: {col}')
# \*Estadísticas de la variable: Criterio Geografico
# Criterio Geografico
# 0 - NINGUNO                                                                        95.884702
# 3 - CERCANÍA A RONDAS DE RIOS Y CANALES                                             1.340658
# 11 - UBICACIÓN EN ZONAS CON ALERTAS AMBIENTALES POR CONTAMINACIÓN                   0.666145
# 4 - CERCANÍA A HUMEDALES                                                            0.602427
# 9 - CERROS ORIENTALES                                                               0.379413
# 6 - CERCANIA AEROPUERTO                                                             0.300892
# 1 - CERCANÍA AL RELLENO SANITARIO                                                   0.287376
# ...

# %% [markdown]
# Datos a destacar: El 68% aproximadamente de las viviendas son casas Y el 55% de las personas habita en Arriendo

# %%
# Variables a comparar y agrupación
grupo = 'Genero'
variables_comparar = ['Tenencia de la Vivienda', 'Ingreso Economico de la Familia']

# %%
for var in variables_comparar:
    print(f'\n📊 Comparación de la variable "{var}" por grupo "{grupo}":\n')

    # Tabla de frecuencias absolutas
    tabla = pd.crosstab(df[grupo], df[var], margins=True)
    print("Frecuencia absoluta:")
    print(tabla)

    # Tabla de porcentajes por fila (grupo)
    tabla_pct = pd.crosstab(df[grupo], df[var], normalize='index') * 100
    print("\nFrecuencia relativa (%):")
    print(tabla_pct.round(2))
# Out:
# 📊 Comparación de la variable "Tenencia de la Vivienda" por grupo "Genero":
#
# Frecuencia absoluta:
# Tenencia de la Vivienda  ARRIENDO  INVASIÓN O POSADA  PROPIA PAGADA  \
# Genero
# FEMENINO                   110846                740          81377
# HOMBRE TRANSGENERO             64                  0             35
# MASCULINO                   60428                418          43976
# MUJER TRANSGENERO              28                  0             22
# NO BINARIO                     24                  0             25
# All                        171390               1158         125435
#
# Tenencia de la Vivienda  PROPIA PAGANDO  SUBARRIENDO     All
# Genero
# FEMENINO                           5788         2476  201227
# HOMBRE TRANSGENERO                    2            2     103
# MASCULINO                          3109         1382  109313
# MUJER TRANSGENERO                     1            0      51
# NO BINARIO                            0            0      49
# ...
